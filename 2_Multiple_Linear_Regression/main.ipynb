# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('50_Startups.csv')
df.head(5)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42  California  166187.94

# %%
x= df.iloc[:,0:4].values
x
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        [144372.41, 118671.85, 383199.62, 'New York'],
#        [142107.34, 91391.77, 366168.42, 'California'],
#        [131876.9, 99814.71, 362861.36, 'New York'],
#        [134615.46, 147198.87, 127716.82, 'California'],
#        [130298.13, 145530.06, 323876.68, 'New York'],
#        [120542.52, 148718.95, 311613.29, 'New York'],
#        [123334.88, 108679.17, 304981.62, 'California'],
#        [101913.08, 110594.11, 229160.95, 'California'],
#        [100671.96, 91790.61, 249744.55, 'Florida'],
#        [93863.75, 127320.38, 249839.44, 'California'],
#        [91992.39, 135495.07, 252664.93, 'California'],
#        [119943.24, 156547.42, 256512.92, 'Florida'],
#        [114523.61, 122616.84, 261776.23, 'New York'],
#        [78013.11, 121597.55, 264346.06, 'California'],
# ...

# %%
y=df.iloc[:,4].values
y
# Out:
# array([192261.83, 191792.06, 191050.39, 182901.99, 166187.94, 156991.12,
#        156122.51, 155752.6 , 152211.77, 149759.96, 146121.95, 144259.4 ,
#        141585.52, 134307.35, 132602.65, 129917.04, 126992.93, 125370.37,
#        124266.9 , 122776.86, 118474.03, 111313.02, 110352.25, 108733.99,
#        108552.04, 107404.34, 105733.54, 105008.31, 103282.38, 101004.64,
#         99937.59,  97483.56,  97427.84,  96778.92,  96712.8 ,  96479.51,
#         90708.19,  89949.14,  81229.06,  81005.76,  78239.91,  77798.83,
#         71498.49,  69758.98,  65200.33,  64926.08,  49490.75,  42559.73,
#         35673.41,  14681.4 ])

# %%
# label encoding
from sklearn.preprocessing import LabelEncoder
Label = LabelEncoder()
x[:,3:]= Label.fit_transform(x[:,3:].ravel()).reshape(-1,1)
x[:,3:]
# Out:
# array([[2],
#        [0],
#        [1],
#        [2],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [0],
#        [0],
#        [1],
#        [0],
#        [0],
#        [1],
#        [2],
#        [0],
#        [2],
#        [2],
#        [1],
#        [0],
#        [2],
#        [0],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [1],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [1],
#        [0],
#        [0],
#        [2],
#        [0],
#        [2],
#        [1],
#        [0],
#        [2],
#        [0]], dtype=object)

# %%
x
# Out:
# array([[165349.2, 136897.8, 471784.1, 2],
#        [162597.7, 151377.59, 443898.53, 0],
#        [153441.51, 101145.55, 407934.54, 1],
#        [144372.41, 118671.85, 383199.62, 2],
#        [142107.34, 91391.77, 366168.42, 0],
#        [131876.9, 99814.71, 362861.36, 2],
#        [134615.46, 147198.87, 127716.82, 0],
#        [130298.13, 145530.06, 323876.68, 2],
#        [120542.52, 148718.95, 311613.29, 2],
#        [123334.88, 108679.17, 304981.62, 0],
#        [101913.08, 110594.11, 229160.95, 0],
#        [100671.96, 91790.61, 249744.55, 1],
#        [93863.75, 127320.38, 249839.44, 0],
#        [91992.39, 135495.07, 252664.93, 0],
#        [119943.24, 156547.42, 256512.92, 1],
#        [114523.61, 122616.84, 261776.23, 2],
#        [78013.11, 121597.55, 264346.06, 0],
#        [94657.16, 145077.58, 282574.31, 2],
#        [91749.16, 114175.79, 294919.57, 2],
#        [86419.7, 153514.11, 0.0, 1],
#        [76253.86, 113867.3, 298664.47, 0],
# ...

# %%
# one hot encoding
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [3])], remainder='passthrough')
x = np.array(ct.fit_transform(x))
print (x)
# Out:
# [[0.0 0.0 1.0 165349.2 136897.8 471784.1]
#  [1.0 0.0 0.0 162597.7 151377.59 443898.53]
#  [0.0 1.0 0.0 153441.51 101145.55 407934.54]
#  [0.0 0.0 1.0 144372.41 118671.85 383199.62]
#  [1.0 0.0 0.0 142107.34 91391.77 366168.42]
#  [0.0 0.0 1.0 131876.9 99814.71 362861.36]
#  [1.0 0.0 0.0 134615.46 147198.87 127716.82]
#  [0.0 0.0 1.0 130298.13 145530.06 323876.68]
#  [0.0 0.0 1.0 120542.52 148718.95 311613.29]
#  [1.0 0.0 0.0 123334.88 108679.17 304981.62]
#  [1.0 0.0 0.0 101913.08 110594.11 229160.95]
#  [0.0 1.0 0.0 100671.96 91790.61 249744.55]
#  [1.0 0.0 0.0 93863.75 127320.38 249839.44]
#  [1.0 0.0 0.0 91992.39 135495.07 252664.93]
#  [0.0 1.0 0.0 119943.24 156547.42 256512.92]
#  [0.0 0.0 1.0 114523.61 122616.84 261776.23]
#  [1.0 0.0 0.0 78013.11 121597.55 264346.06]
#  [0.0 0.0 1.0 94657.16 145077.58 282574.31]
#  [0.0 0.0 1.0 91749.16 114175.79 294919.57]
#  [0.0 1.0 0.0 86419.7 153514.11 0.0]
#  [1.0 0.0 0.0 76253.86 113867.3 298664.47]
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print ('X Shape-',x.shape)
print ('Y Shape-', y.shape)
print ('X_Train Shape-',x_train.shape)
print ('Y_Train Shape-',y_train.shape)
print ('X_Test Shape-',x_test.shape)
print ('Y_Test Shape-',y_test.shape)
# Out:
# X Shape- (50, 6)
# Y Shape- (50,)
# X_Train Shape- (40, 6)
# Y_Train Shape- (40,)
# X_Test Shape- (10, 6)
# Y_Test Shape- (10,)

# %%
x_train.dtype , y_train.dtype
# Out:
# (dtype('O'), dtype('float64'))

# %%
y_train
# Out:
# array([141585.52, 166187.94,  89949.14, 152211.77, 182901.99, 156122.51,
#         77798.83,  49490.75,  42559.73, 129917.04, 149759.96, 126992.93,
#        108552.04,  96712.8 ,  97483.56, 192261.83,  65200.33, 105008.31,
#         96778.92, 156991.12, 101004.64, 144259.4 ,  90708.19, 191792.06,
#        111313.02, 191050.39,  69758.98,  96479.51, 108733.99,  78239.91,
#        146121.95, 110352.25, 124266.9 ,  14681.4 , 118474.03, 155752.6 ,
#         71498.49, 132602.65, 103282.38,  81229.06])

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lr.predict(x_test)
y_predict
# Out:
# array([125685.70020549,  84338.92317125,  99390.9365877 ,  46818.58913861,
#        128971.45588835,  52062.2988212 , 109174.11382464,  99985.25961747,
#         97162.65075522, 115228.18387683])

# %%
y_test
# Out:
# array([134307.35,  81005.76,  99937.59,  64926.08, 125370.37,  35673.41,
#        105733.54, 107404.34,  97427.84, 122776.86])

# %%
result = pd.concat([pd.DataFrame(y_predict, columns = ['Prediction']),
                    pd.DataFrame(y_test,columns = ['Y_Test'])], axis =1)
result['Difference']= y_test -y_predict
print (result)
# Out:
#       Prediction     Y_Test    Difference
# 0  125685.700205  134307.35   8621.649795
# 1   84338.923171   81005.76  -3333.163171
# 2   99390.936588   99937.59    546.653412
# 3   46818.589139   64926.08  18107.490861
# 4  128971.455888  125370.37  -3601.085888
# 5   52062.298821   35673.41 -16388.888821
# 6  109174.113825  105733.54  -3440.573825
# 7   99985.259617  107404.34   7419.080383
# 8   97162.650755   97427.84    265.189245
# 9  115228.183877  122776.86   7548.676123

# %%
plt.plot(x_test,y_test)

# %%
import seaborn as sns
sns.regplot(x=y_predict ,y=y_test,scatter_kws={"color":"b"},
            line_kws={'color':"r"},ci=None)
# Out:
# <Axes: >

# %%
x_test
y_test
# Out:
# array([134307.35,  81005.76,  99937.59,  64926.08, 125370.37,  35673.41,
#        105733.54, 107404.34,  97427.84, 122776.86])

# %%
Y_Test=pd.DataFrame(y_test,columns=['Y_Test'])
X_Test=pd.DataFrame(x_test,columns=['CF','FR','New Y','R&D','Admin','Mark'])
Y_Prediction=pd.DataFrame(y_predict,columns=['Prediction'])
result= pd.concat([X_Test,Y_Test,Y_Prediction],axis=1)
result['Difference']=result['Prediction']-result['Y_Test']
result
# Out:
#     CF   FR New Y       R&D      Admin       Mark     Y_Test     Prediction  \
# 0  1.0  0.0   0.0  91992.39  135495.07  252664.93  134307.35  125685.700205
# 1  1.0  0.0   0.0  38558.51   82982.09   174999.3   81005.76   84338.923171
# 2  0.0  0.0   1.0  61994.48  115641.28   91131.24   99937.59   99390.936588
# 3  0.0  0.0   1.0   1000.23  124153.04    1903.93   64926.08   46818.589139
# 4  0.0  0.0   1.0  94657.16  145077.58  282574.31  125370.37  128971.455888
# 5  0.0  0.0   1.0    542.05   51743.15        0.0   35673.41   52062.298821
# 6  0.0  0.0   1.0  75328.87  144135.98  134050.07  105733.54  109174.113825
# 7  1.0  0.0   0.0  64664.71  139553.16  137962.62  107404.34   99985.259617
# 8  1.0  0.0   0.0  63408.86  129219.61   46085.25   97427.84   97162.650755
# 9  0.0  1.0   0.0   86419.7  153514.11        0.0  122776.86  115228.183877
#
#      Difference
# 0  -8621.649795
# 1   3333.163171
# 2   -546.653412
# 3 -18107.490861
# 4   3601.085888
# 5  16388.888821
# ...

# %%
from sklearn.metrics import r2_score
accuracy = r2_score(y_test,y_predict)
accuracy
# Out:
# 0.8988481687284672

# %%
# y = mx +c
# y =  m1x1+m2x2+m3x3+m4x4+m5x5+m6x6+c

# %%
print(lr.coef_)
print()
print(lr.intercept_)
# Out:
# [-1.22767929e+03  1.42750258e+03 -1.99823287e+02  8.09359318e-01
#  -7.82867439e-02  2.84635373e-02]
#
# 55874.21162474303

# %%
-1.22767929e+03 *1.0 +  8.09359318e-01*91992.39	+-7.82867439e-02*135495.07 + 2.84635373e-02*252664.93+55874.21162474303
# Out:
# 125685.70018098736

# %%
y_fullPredict = lr.predict(x)
y_fullPredict
# Out:
# array([192212.66545476, 187030.55971071, 185183.93437007, 174140.32762989,
#        172930.11655406, 164924.33544176, 155710.36151198, 158957.99543862,
#        150463.49430467, 154641.48410325, 134995.5117714 , 138704.12846331,
#        127759.84928264, 125685.70020549, 149424.57045842, 146216.9435966 ,
#        115791.91754096, 128971.45588835, 129388.42927958, 115228.18387683,
#        115950.05160436, 115612.79873556, 113555.99633349, 109700.5070828 ,
#        114259.51926275,  99985.25961747, 109174.11382464, 114078.10758207,
#         99825.31692068,  99841.95049278,  99390.9365877 ,  95712.15395366,
#         97162.65075522,  98630.1644703 ,  88531.79037815,  92107.9360512 ,
#         74651.63335331,  91908.32121704,  72157.84688136,  84338.92317125,
#         76212.09086725,  75271.61487551,  70462.80150001,  59263.17807134,
#         61283.53057794,  46818.58913861,  57756.44854212,  44044.3997219 ,
#         52062.2988212 ,  46774.03661174])

# %%
display(result)
# Out:
#     CF   FR New Y       R&D      Admin       Mark     Y_Test     Prediction  \
# 0  1.0  0.0   0.0  91992.39  135495.07  252664.93  134307.35  125685.700205
# 1  1.0  0.0   0.0  38558.51   82982.09   174999.3   81005.76   84338.923171
# 2  0.0  0.0   1.0  61994.48  115641.28   91131.24   99937.59   99390.936588
# 3  0.0  0.0   1.0   1000.23  124153.04    1903.93   64926.08   46818.589139
# 4  0.0  0.0   1.0  94657.16  145077.58  282574.31  125370.37  128971.455888
# 5  0.0  0.0   1.0    542.05   51743.15        0.0   35673.41   52062.298821
# 6  0.0  0.0   1.0  75328.87  144135.98  134050.07  105733.54  109174.113825
# 7  1.0  0.0   0.0  64664.71  139553.16  137962.62  107404.34   99985.259617
# 8  1.0  0.0   0.0  63408.86  129219.61   46085.25   97427.84   97162.650755
# 9  0.0  1.0   0.0   86419.7  153514.11        0.0  122776.86  115228.183877
#
#      Difference
# 0  -8621.649795
# 1   3333.163171
# 2   -546.653412
# 3 -18107.490861
# 4   3601.085888
# 5  16388.888821
# ...

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42  California  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68    New York  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95  California  146121.95
# 11  100671.96        91790.61        249744.55     Florida  144259.40
# ...

# %%
Y_FullPredict = pd.DataFrame(y_fullPredict,columns=['Prediction'])
result = pd.concat([df,Y_FullPredict],axis=1)
result['Difference']=result['Profit']-result['Prediction']
result
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42  California  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68    New York  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95  California  146121.95
# 11  100671.96        91790.61        249744.55     Florida  144259.40
# ...

# %%
accuracy = r2_score(y,y_fullPredict)
accuracy
# Out:
# 0.9499635752382207

# %%
sns.regplot(x=y_fullPredict,y=y,scatter_kws={"color":"g"},
            line_kws={"color":"r"},ci=None)
# Out:
# <Axes: >

# %%
x=x.astype('float64')
x
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.6534920e+05,
#         1.3689780e+05, 4.7178410e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.6259770e+05,
#         1.5137759e+05, 4.4389853e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.5344151e+05,
#         1.0114555e+05, 4.0793454e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.4437241e+05,
#         1.1867185e+05, 3.8319962e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.4210734e+05,
#         9.1391770e+04, 3.6616842e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.3187690e+05,
#         9.9814710e+04, 3.6286136e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3461546e+05,
#         1.4719887e+05, 1.2771682e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.3029813e+05,
#         1.4553006e+05, 3.2387668e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.2054252e+05,
#         1.4871895e+05, 3.1161329e+05],
# ...

# %%
import statsmodels.api as sm
reg_ols = sm.OLS (endog = y, exog = x)
reg_ols = reg_ols.fit()
print (reg_ols.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     171.2
# Date:                Tue, 30 Jul 2024   Prob (F-statistic):           1.14e-27
# Time:                        10:50:02   Log-Likelihood:                -525.19
# No. Observations:                  50   AIC:                             1062.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          5.062e+04   6806.869      7.436      0.000    3.69e+04    6.43e+04
# ...

# %%
x_opt=x[:,[0,1,2,3,5]]
import statsmodels.api as sm
reg_ols = sm.OLS (endog = y, exog =x_opt)
reg_ols = reg_ols.fit()
print (reg_ols.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     216.9
# Date:                Tue, 30 Jul 2024   Prob (F-statistic):           8.77e-29
# Time:                        10:50:23   Log-Likelihood:                -525.42
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          4.681e+04   3130.528     14.954      0.000    4.05e+04    5.31e+04
# ...
