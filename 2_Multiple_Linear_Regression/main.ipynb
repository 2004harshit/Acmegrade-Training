# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df= pd.read_csv('50_Startups.csv')

# %%
df.head(5)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42  California  166187.94

# %%
# extrating x dataset from the dataframe
x=df.iloc[0:,0:4].values
x
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        [144372.41, 118671.85, 383199.62, 'New York'],
#        [142107.34, 91391.77, 366168.42, 'California'],
#        [131876.9, 99814.71, 362861.36, 'New York'],
#        [134615.46, 147198.87, 127716.82, 'California'],
#        [130298.13, 145530.06, 323876.68, 'New York'],
#        [120542.52, 148718.95, 311613.29, 'New York'],
#        [123334.88, 108679.17, 304981.62, 'California'],
#        [101913.08, 110594.11, 229160.95, 'California'],
#        [100671.96, 91790.61, 249744.55, 'Florida'],
#        [93863.75, 127320.38, 249839.44, 'California'],
#        [91992.39, 135495.07, 252664.93, 'California'],
#        [119943.24, 156547.42, 256512.92, 'Florida'],
#        [114523.61, 122616.84, 261776.23, 'New York'],
#        [78013.11, 121597.55, 264346.06, 'California'],
# ...

# %%
# exracting y dataset
y= df.iloc[0:,4:].values
y
# Out:
# array([[192261.83],
#        [191792.06],
#        [191050.39],
#        [182901.99],
#        [166187.94],
#        [156991.12],
#        [156122.51],
#        [155752.6 ],
#        [152211.77],
#        [149759.96],
#        [146121.95],
#        [144259.4 ],
#        [141585.52],
#        [134307.35],
#        [132602.65],
#        [129917.04],
#        [126992.93],
#        [125370.37],
#        [124266.9 ],
#        [122776.86],
#        [118474.03],
#        [111313.02],
#        [110352.25],
#        [108733.99],
#        [108552.04],
#        [107404.34],
#        [105733.54],
#        [105008.31],
#        [103282.38],
#        [101004.64],
#        [ 99937.59],
#        [ 97483.56],
#        [ 97427.84],
#        [ 96778.92],
#        [ 96712.8 ],
#        [ 96479.51],
#        [ 90708.19],
#        [ 89949.14],
#        [ 81229.06],
#        [ 81005.76],
#        [ 78239.91],
#        [ 77798.83],
#        [ 71498.49],
#        [ 69758.98],
#        [ 65200.33],
# ...

# %%
#  since x contain categorical data so we will convert this categorical data into numerical data
# following methods are employed to do this task
# 1.Label Encoding
# 2.One-Hot Encoding

# 1.Label -Encoding: involves assigning a unique integer to each
#  category in a categorical feature. For example, if you have a 
# feature "Color" with categories "Red," "Blue," and "Green,"
#  label encoding would transform these categories into 
# numerical values such as:
# "Red" -> 2
# "Blue" -> 0
# "Green" -> 1

# 2.One-Hot Encoding : One-hot encoding addresses the issue of
#  implied ordinality by creating a new binary column (0 or 1) 
# for each category. Each row in the dataset will have a 1 in the 
# column corresponding to its category and 0s in all other 
# columns. For the same "Color" feature, one-hot encoding
#  would create three new columns:

# Color_Red: [1, 0, 0] (for Red)
# Color_Blue: [0, 1, 0] (for Blue)
# Color_Green: [0, 0, 1] (for Green)

# %%
# Label.fit_transform(x[:, 3:]).shape
# x[:,2:].shape[1]
print(x[:,3:].ndim)
# print(x[:,3:].ravel().ndim)
print(x[:,3:].shape)
# Out:
# 2
# (50, 1)

# %%
from sklearn.preprocessing import LabelEncoder
Label = LabelEncoder()
x[:, 3:]= Label.fit_transform(x[:, 3:].ravel()).reshape(50,1)
x
# Out:
# array([[165349.2, 136897.8, 471784.1, 2],
#        [162597.7, 151377.59, 443898.53, 0],
#        [153441.51, 101145.55, 407934.54, 1],
#        [144372.41, 118671.85, 383199.62, 2],
#        [142107.34, 91391.77, 366168.42, 0],
#        [131876.9, 99814.71, 362861.36, 2],
#        [134615.46, 147198.87, 127716.82, 0],
#        [130298.13, 145530.06, 323876.68, 2],
#        [120542.52, 148718.95, 311613.29, 2],
#        [123334.88, 108679.17, 304981.62, 0],
#        [101913.08, 110594.11, 229160.95, 0],
#        [100671.96, 91790.61, 249744.55, 1],
#        [93863.75, 127320.38, 249839.44, 0],
#        [91992.39, 135495.07, 252664.93, 0],
#        [119943.24, 156547.42, 256512.92, 1],
#        [114523.61, 122616.84, 261776.23, 2],
#        [78013.11, 121597.55, 264346.06, 0],
#        [94657.16, 145077.58, 282574.31, 2],
#        [91749.16, 114175.79, 294919.57, 2],
#        [86419.7, 153514.11, 0.0, 1],
#        [76253.86, 113867.3, 298664.47, 0],
# ...

# %%
x
# Out:
# array([[165349.2, 136897.8, 471784.1, 2],
#        [162597.7, 151377.59, 443898.53, 0],
#        [153441.51, 101145.55, 407934.54, 1],
#        [144372.41, 118671.85, 383199.62, 2],
#        [142107.34, 91391.77, 366168.42, 0],
#        [131876.9, 99814.71, 362861.36, 2],
#        [134615.46, 147198.87, 127716.82, 0],
#        [130298.13, 145530.06, 323876.68, 2],
#        [120542.52, 148718.95, 311613.29, 2],
#        [123334.88, 108679.17, 304981.62, 0],
#        [101913.08, 110594.11, 229160.95, 0],
#        [100671.96, 91790.61, 249744.55, 1],
#        [93863.75, 127320.38, 249839.44, 0],
#        [91992.39, 135495.07, 252664.93, 0],
#        [119943.24, 156547.42, 256512.92, 1],
#        [114523.61, 122616.84, 261776.23, 2],
#        [78013.11, 121597.55, 264346.06, 0],
#        [94657.16, 145077.58, 282574.31, 2],
#        [91749.16, 114175.79, 294919.57, 2],
#        [86419.7, 153514.11, 0.0, 1],
#        [76253.86, 113867.3, 298664.47, 0],
# ...

# %% [markdown]
# #### __Sparse Matrix :__
# * a sparse matrix is a matrix that is primarily composed of zero or empty elements. This means that only a small proportion of the elements have non-zero values, while the vast majority are zeros.<br>
# * Sparse matrices are common in various applications, such as natural language processing (NLP), recommender systems, and one-hot encoding of categorical variables.<br>
# #### __Applications of Sparse Matrices :__<br>
# __1 . Natural Language Processing (NLP) :__ Text data is often represented as a bag-of-words or TF-IDF matrix, where each document is a vector, and each dimension represents a term. Most documents contain only a small subset of all possible terms, leading to sparsity.<br>
# __2. Recommender Systems :__ User-item interaction matrices, where most users interact with a small fraction of items, resulting in many zero entries.<br>
# __3. One-Hot Encoding :__ When encoding categorical variables, each category is represented as a binary vector, leading to many zeros if the number of categories is large.<br>
# __4. Graph Data :__ Adjacency matrices in graph representations are often sparse because most nodes are not directly connected to each other.<br>

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct= ColumnTransformer([('encoder',OneHotEncoder(),[3])],remainder='passthrough')
# print(ct)
# ct.fit_transform(x)
# x= ct.fit_transform(x)
x= np.array(ct.fit_transform(x))
# x.shape,x
print(x)
# Out:
# [[0.0 0.0 1.0 165349.2 136897.8 471784.1]
#  [1.0 0.0 0.0 162597.7 151377.59 443898.53]
#  [0.0 1.0 0.0 153441.51 101145.55 407934.54]
#  [0.0 0.0 1.0 144372.41 118671.85 383199.62]
#  [1.0 0.0 0.0 142107.34 91391.77 366168.42]
#  [0.0 0.0 1.0 131876.9 99814.71 362861.36]
#  [1.0 0.0 0.0 134615.46 147198.87 127716.82]
#  [0.0 0.0 1.0 130298.13 145530.06 323876.68]
#  [0.0 0.0 1.0 120542.52 148718.95 311613.29]
#  [1.0 0.0 0.0 123334.88 108679.17 304981.62]
#  [1.0 0.0 0.0 101913.08 110594.11 229160.95]
#  [0.0 1.0 0.0 100671.96 91790.61 249744.55]
#  [1.0 0.0 0.0 93863.75 127320.38 249839.44]
#  [1.0 0.0 0.0 91992.39 135495.07 252664.93]
#  [0.0 1.0 0.0 119943.24 156547.42 256512.92]
#  [0.0 0.0 1.0 114523.61 122616.84 261776.23]
#  [1.0 0.0 0.0 78013.11 121597.55 264346.06]
#  [0.0 0.0 1.0 94657.16 145077.58 282574.31]
#  [0.0 0.0 1.0 91749.16 114175.79 294919.57]
#  [0.0 1.0 0.0 86419.7 153514.11 0.0]
#  [1.0 0.0 0.0 76253.86 113867.3 298664.47]
# ...

# %%
from sklearn.model_selection import  train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print ('X Shape-',x.shape)
print ('Y Shape-', y.shape)
print ('X_train Shape-',x_train.shape)
print ('Y_train Shape-',y_train.shape)
print ('X_test Shape-',x_test.shape)
print ('Y_test Shape-',y_test.shape)
# Out:
# X Shape- (50, 6)
# Y Shape- (50, 1)
# X_train Shape- (40, 6)
# Y_train Shape- (40, 1)
# X_test Shape- (10, 6)
# Y_test Shape- (10, 1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predicted=lr.predict(x_test)

# %%
c1=pd.DataFrame(y_test,columns=['y_Test'])
c2 =pd.DataFrame(y_predicted,columns=['Prediction'])
# print(c1,c2)
result=pd.concat([c1,c2],axis=1)
# c1+c2
result['difference'] =result['Prediction']-result['y_Test']
result
# Out:
#       y_Test     Prediction    difference
# 0  134307.35  125685.700205  -8621.649795
# 1   81005.76   84338.923171   3333.163171
# 2   99937.59   99390.936588   -546.653412
# 3   64926.08   46818.589139 -18107.490861
# 4  125370.37  128971.455888   3601.085888
# 5   35673.41   52062.298821  16388.888821
# 6  105733.54  109174.113825   3440.573825
# 7  107404.34   99985.259617  -7419.080383
# 8   97427.84   97162.650755   -265.189245
# 9  122776.86  115228.183877  -7548.676123

# %%
sns.regplot(x=y_predicted,y=None,scatter_kws={"color":"r"},
            line_kws={"color":"b"},ci=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 sns.regplot(x=y_predicted,y=None,scatter_kws={"color":"r"},
#       2             line_kws={"color":"b"},ci=None)
#
# File /workspaces/Acmegrade-Training/.conda/lib/python3.11/site-packages/seaborn/regression.py:775, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     773 scatter_kws["marker"] = marker
#     774 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 775 plotter.plot(ax, scatter_kws, line_kws)
#     776 return ax
#
# File /workspaces/Acmegrade-Training/.conda/lib/python3.11/site-packages/seaborn/regression.py:381, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
# ...

# %%
data = sns.load_dataset('tips')
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x=data['total_bill'],y=data['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.scatter(data['tota'],y_test)
plt.plot(x_test,y_predicted,'r')
